# %%
import requests 
from bs4 import BeautifulSoup

# %%
def links(urls, x):
    """
    Function to get website urls
    Takes in a url from any website 
    and a filter by to search for what urls start with
    
    """
    new_list = []
    content = requests.get(urls)

    soup = BeautifulSoup(content.text, 'html.parser')
    href = soup.find_all('a', href = True)
    for link in href:
        if link['href'].startswith(x):
            new_list.append(link['href'])
    
    return new_list

# %%
link_2016 = 'https://www.hltv.org/stats/players?startDate=2016-01-01&endDate=2016-12-31&rankingFilter=Top50'
link_2017 = 'https://www.hltv.org/stats/players?startDate=2017-01-01&endDate=2017-12-31&rankingFilter=Top50'
link_2018 = 'https://www.hltv.org/stats/players?startDate=2018-01-01&endDate=2018-12-31&rankingFilter=Top50'
link_2019 = 'https://www.hltv.org/stats/players?startDate=2019-01-01&endDate=2019-12-31&rankingFilter=Top50'

# %%
players_url = genre_links(link_2019, "/stats/players/", 50)

# %%
len(players_url)
# Out:
# 50

# %%
list_19_t50 = []
for link in players_url:
    
    home_url = "https://www.hltv.org/" + link
    
    req_url = requests.get(home_url)
        
    soup = BeautifulSoup(req_url.text)
    
    player_dict = {}
    
    player_dict['Name'] = soup.find('h1').text
    
    data = soup.find_all('span')
    
    for i, span in enumerate(data):
        if 'Total kills' in span:
            player_dict['total_kills'] = data[i+1].text
        if 'Headshot %' in span:
            player_dict['headshot_%'] = data[i+1].text
        if 'Total deaths' in span:
            player_dict['total_deaths'] = data[i+1].text
        if 'K/D Ratio' in span:
            player_dict['k/d_ratio'] = data[i+1].text
        if 'Damage / Round' in span:
            player_dict['damage/round'] = data[i+1].text
        if 'Grenade dmg / Round' in span:
            player_dict['grenadedmg/round'] = data[i+1].text
        if 'Maps played' in span:
            player_dict['maps_played'] = data[i+1].text
        if 'Rounds played' in span:
            player_dict['rounds_played'] = data[i+1].text
        if 'Kills / round' in span:
            player_dict['kills/round'] = data[i+1].text
        if 'Assists / round' in span:
            player_dict['assists/round'] = data[i+1].text
        if 'Deaths / round' in span:
            player_dict['death/round'] = data[i+1].text
        if 'Saved by teammate / round' in span:
            player_dict['savedbyteammate/round'] = data[i+1].text
        if 'Saved teammates / round' in span:
            player_dict['savedteammates/round'] = data[i+1].text
        if 'Rating 1.0' in span:
            player_dict['rating_1.0'] = data[i+1].text
    list_19_t50.append(player_dict)

# %%
list_16_t50
# Out:
# [{'Name': 'coldzera',
#   'total_kills': '5013',
#   'headshot_%': '45.6%',
#   'total_deaths': '3730',
#   'k/d_ratio': '1.34',
#   'damage/round': '83.9',
#   'grenadedmg/round': '2.1',
#   'maps_played': '238',
#   'rounds_played': '6149',
#   'kills/round': '0.82',
#   'assists/round': '0.12',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.22'},
#  {'Name': 'oskar',
#   'total_kills': '3642',
#   'headshot_%': '27.5%',
#   'total_deaths': '2864',
#   'k/d_ratio': '1.27',
#   'damage/round': '83.9',
#   'grenadedmg/round': '3.0',
#   'maps_played': '171',
#   'rounds_played': '4508',
#   'kills/round': '0.81',
#   'assists/round': '0.12',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.19'},
#  {'Name': 'device',
#   'total_kills': '5032',
#   'headshot_%': '32.0%',
#   'total_deaths': '3963',
#   'k/d_ratio': '1.27',
#   'damage/round': '82.2',
#   'grenadedmg/round': '3.5',
#   'maps_played': '247',
#   'rounds_played': '6374',
#   'kills/round': '0.79',
#   'assists/round': '0.12',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.18'},
#  {'Name': 'HEN1',
#   'total_kills': '4372',
#   'headshot_%': '25.3%',
#   'total_deaths': '3296',
#   'k/d_ratio': '1.33',
#   'damage/round': '76.8',
#   'grenadedmg/round': '2.3',
#   'maps_played': '225',
#   'rounds_played': '5854',
#   'kills/round': '0.75',
#   'assists/round': '0.11',
#   'death/round': '0.56',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.17'},
#  {'Name': 'NiKo',
#   'total_kills': '4382',
#   'headshot_%': '50.5%',
#   'total_deaths': '3774',
#   'k/d_ratio': '1.16',
#   'damage/round': '88.2',
#   'grenadedmg/round': '2.6',
#   'maps_played': '201',
#   'rounds_played': '5403',
#   'kills/round': '0.81',
#   'assists/round': '0.13',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.16'},
#  {'Name': 'Magisk',
#   'total_kills': '6152',
#   'headshot_%': '48.4%',
#   'total_deaths': '5100',
#   'k/d_ratio': '1.21',
#   'damage/round': '83.3',
#   'grenadedmg/round': '4.1',
#   'maps_played': '308',
#   'rounds_played': '8041',
#   'kills/round': '0.77',
#   'assists/round': '0.14',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.14'},
#  {'Name': 'shox',
#   'total_kills': '4707',
#   'headshot_%': '48.5%',
#   'total_deaths': '4038',
#   'k/d_ratio': '1.17',
#   'damage/round': '85.0',
#   'grenadedmg/round': '1.7',
#   'maps_played': '225',
#   'rounds_played': '5935',
#   'kills/round': '0.79',
#   'assists/round': '0.12',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.13'},
#  {'Name': 'kennyS',
#   'total_kills': '4330',
#   'headshot_%': '32.3%',
#   'total_deaths': '3615',
#   'k/d_ratio': '1.20',
#   'damage/round': '76.0',
#   'grenadedmg/round': '3.7',
#   'maps_played': '218',
#   'rounds_played': '5727',
#   'kills/round': '0.76',
#   'assists/round': '0.10',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.12'},
#  {'Name': 'FalleN',
#   'total_kills': '4445',
#   'headshot_%': '28.7%',
#   'total_deaths': '3581',
#   'k/d_ratio': '1.24',
#   'damage/round': '74.9',
#   'grenadedmg/round': '3.1',
#   'maps_played': '238',
#   'rounds_played': '6149',
#   'kills/round': '0.72',
#   'assists/round': '0.11',
#   'death/round': '0.58',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.12'},
#  {'Name': 'WorldEdit',
#   'total_kills': '4576',
#   'headshot_%': '24.4%',
#   'total_deaths': '3982',
#   'k/d_ratio': '1.15',
#   'damage/round': '80.0',
#   'grenadedmg/round': '2.8',
#   'maps_played': '230',
#   'rounds_played': '5916',
#   'kills/round': '0.77',
#   'assists/round': '0.12',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.12'},
#  {'Name': 'mixwell',
#   'total_kills': '3937',
#   'headshot_%': '39.1%',
#   'total_deaths': '3406',
#   'k/d_ratio': '1.16',
#   'damage/round': '80.3',
#   'grenadedmg/round': '5.2',
#   'maps_played': '203',
#   'rounds_played': '5160',
#   'kills/round': '0.76',
#   'assists/round': '0.13',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'bubble',
#   'total_kills': '5124',
#   'headshot_%': '39.6%',
#   'total_deaths': '4358',
#   'k/d_ratio': '1.18',
#   'damage/round': '82.3',
#   'grenadedmg/round': '4.8',
#   'maps_played': '255',
#   'rounds_played': '6758',
#   'kills/round': '0.76',
#   'assists/round': '0.16',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.11'},
#  {'Name': 'valde',
#   'total_kills': '3923',
#   'headshot_%': '46.6%',
#   'total_deaths': '3454',
#   'k/d_ratio': '1.14',
#   'damage/round': '83.9',
#   'grenadedmg/round': '4.1',
#   'maps_played': '191',
#   'rounds_played': '5039',
#   'kills/round': '0.78',
#   'assists/round': '0.14',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'ScreaM',
#   'total_kills': '4528',
#   'headshot_%': '64.8%',
#   'total_deaths': '3949',
#   'k/d_ratio': '1.15',
#   'damage/round': '82.4',
#   'grenadedmg/round': '2.6',
#   'maps_played': '225',
#   'rounds_played': '5935',
#   'kills/round': '0.76',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12',
#   'rating_1.0': '1.11'},
#  {'Name': 'flusha',
#   'total_kills': '4317',
#   'headshot_%': '40.7%',
#   'total_deaths': '3757',
#   'k/d_ratio': '1.15',
#   'damage/round': '86.4',
#   'grenadedmg/round': '8.0',
#   'maps_played': '222',
#   'rounds_played': '5741',
#   'kills/round': '0.75',
#   'assists/round': '0.18',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.10'},
#  {'Name': 'autimatic',
#   'total_kills': '4256',
#   'headshot_%': '48.2%',
#   'total_deaths': '3737',
#   'k/d_ratio': '1.14',
#   'damage/round': '82.7',
#   'grenadedmg/round': '2.8',
#   'maps_played': '212',
#   'rounds_played': '5535',
#   'kills/round': '0.77',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'dream3r',
#   'total_kills': '3463',
#   'headshot_%': '50.1%',
#   'total_deaths': '2951',
#   'k/d_ratio': '1.17',
#   'damage/round': '78.6',
#   'grenadedmg/round': '2.8',
#   'maps_played': '176',
#   'rounds_played': '4663',
#   'kills/round': '0.74',
#   'assists/round': '0.12',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.10'},
#  {'Name': 'boltz',
#   'total_kills': '4306',
#   'headshot_%': '37.4%',
#   'total_deaths': '3690',
#   'k/d_ratio': '1.17',
#   'damage/round': '84.1',
#   'grenadedmg/round': '8.3',
#   'maps_played': '225',
#   'rounds_played': '5854',
#   'kills/round': '0.74',
#   'assists/round': '0.17',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.09'},
#  {'Name': 'cajunb',
#   'total_kills': '5629',
#   'headshot_%': '38.0%',
#   'total_deaths': '4801',
#   'k/d_ratio': '1.17',
#   'damage/round': '76.4',
#   'grenadedmg/round': '2.2',
#   'maps_played': '299',
#   'rounds_played': '7697',
#   'kills/round': '0.73',
#   'assists/round': '0.12',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.09'},
#  {'Name': 'k0nfig',
#   'total_kills': '6246',
#   'headshot_%': '55.6%',
#   'total_deaths': '5682',
#   'k/d_ratio': '1.10',
#   'damage/round': '81.3',
#   'grenadedmg/round': '2.3',
#   'maps_played': '318',
#   'rounds_played': '8224',
#   'kills/round': '0.76',
#   'assists/round': '0.13',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.09'},
#  {'Name': 'keev',
#   'total_kills': '3531',
#   'headshot_%': '28.0%',
#   'total_deaths': '3141',
#   'k/d_ratio': '1.12',
#   'damage/round': '77.5',
#   'grenadedmg/round': '2.9',
#   'maps_played': '180',
#   'rounds_played': '4693',
#   'kills/round': '0.75',
#   'assists/round': '0.10',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.09'},
#  {'Name': 'Kjaerbye',
#   'total_kills': '5020',
#   'headshot_%': '53.5%',
#   'total_deaths': '4463',
#   'k/d_ratio': '1.12',
#   'damage/round': '82.2',
#   'grenadedmg/round': '3.3',
#   'maps_played': '259',
#   'rounds_played': '6690',
#   'kills/round': '0.75',
#   'assists/round': '0.16',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.09'},
#  {'Name': 'AdreN',
#   'total_kills': '3723',
#   'headshot_%': '49.9%',
#   'total_deaths': '3421',
#   'k/d_ratio': '1.09',
#   'damage/round': '85.0',
#   'grenadedmg/round': '5.0',
#   'maps_played': '184',
#   'rounds_played': '4867',
#   'kills/round': '0.76',
#   'assists/round': '0.16',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.09'},
#  {'Name': 'allu',
#   'total_kills': '5245',
#   'headshot_%': '30.2%',
#   'total_deaths': '4604',
#   'k/d_ratio': '1.14',
#   'damage/round': '77.5',
#   'grenadedmg/round': '3.4',
#   'maps_played': '262',
#   'rounds_played': '6980',
#   'kills/round': '0.75',
#   'assists/round': '0.11',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.09'},
#  {'Name': 'f0rest',
#   'total_kills': '3971',
#   'headshot_%': '45.9%',
#   'total_deaths': '3473',
#   'k/d_ratio': '1.14',
#   'damage/round': '77.6',
#   'grenadedmg/round': '2.1',
#   'maps_played': '203',
#   'rounds_played': '5296',
#   'kills/round': '0.75',
#   'assists/round': '0.11',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.09'},
#  {'Name': 'loWel',
#   'total_kills': '3394',
#   'headshot_%': '44.8%',
#   'total_deaths': '3047',
#   'k/d_ratio': '1.11',
#   'damage/round': '82.5',
#   'grenadedmg/round': '4.5',
#   'maps_played': '171',
#   'rounds_played': '4514',
#   'kills/round': '0.75',
#   'assists/round': '0.15',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.13'},
#  {'Name': 'dennis',
#   'total_kills': '3622',
#   'headshot_%': '55.0%',
#   'total_deaths': '3278',
#   'k/d_ratio': '1.10',
#   'damage/round': '79.1',
#   'grenadedmg/round': '3.5',
#   'maps_played': '185',
#   'rounds_played': '4817',
#   'kills/round': '0.75',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.12',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.08'},
#  {'Name': 'dupreeh',
#   'total_kills': '4607',
#   'headshot_%': '53.1%',
#   'total_deaths': '4077',
#   'k/d_ratio': '1.13',
#   'damage/round': '79.0',
#   'grenadedmg/round': '1.9',
#   'maps_played': '242',
#   'rounds_played': '6213',
#   'kills/round': '0.74',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.08'},
#  {'Name': 'fer',
#   'total_kills': '4515',
#   'headshot_%': '41.6%',
#   'total_deaths': '4056',
#   'k/d_ratio': '1.11',
#   'damage/round': '85.2',
#   'grenadedmg/round': '4.3',
#   'maps_played': '232',
#   'rounds_played': '5997',
#   'kills/round': '0.75',
#   'assists/round': '0.17',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.08'},
#  {'Name': 'shroud',
#   'total_kills': '4749',
#   'headshot_%': '55.0%',
#   'total_deaths': '4139',
#   'k/d_ratio': '1.15',
#   'damage/round': '78.1',
#   'grenadedmg/round': '4.2',
#   'maps_played': '253',
#   'rounds_played': '6578',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.12',
#   'rating_1.0': '1.08'},
#  {'Name': 'znajder',
#   'total_kills': '3659',
#   'headshot_%': '42.7%',
#   'total_deaths': '3218',
#   'k/d_ratio': '1.14',
#   'damage/round': '79.5',
#   'grenadedmg/round': '4.5',
#   'maps_played': '188',
#   'rounds_played': '4883',
#   'kills/round': '0.75',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'GeT_RiGhT',
#   'total_kills': '3973',
#   'headshot_%': '49.3%',
#   'total_deaths': '3587',
#   'k/d_ratio': '1.11',
#   'damage/round': '84.0',
#   'grenadedmg/round': '3.7',
#   'maps_played': '203',
#   'rounds_played': '5296',
#   'kills/round': '0.75',
#   'assists/round': '0.15',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.08'},
#  {'Name': 'felps',
#   'total_kills': '4614',
#   'headshot_%': '43.7%',
#   'total_deaths': '4248',
#   'k/d_ratio': '1.09',
#   'damage/round': '86.3',
#   'grenadedmg/round': '3.0',
#   'maps_played': '225',
#   'rounds_played': '5854',
#   'kills/round': '0.79',
#   'assists/round': '0.16',
#   'death/round': '0.73',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.08'},
#  {'Name': 'rain',
#   'total_kills': '4178',
#   'headshot_%': '53.2%',
#   'total_deaths': '3897',
#   'k/d_ratio': '1.07',
#   'damage/round': '83.8',
#   'grenadedmg/round': '1.9',
#   'maps_played': '211',
#   'rounds_played': '5573',
#   'kills/round': '0.75',
#   'assists/round': '0.15',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.07'},
#  {'Name': 'draken',
#   'total_kills': '4329',
#   'headshot_%': '30.7%',
#   'total_deaths': '3894',
#   'k/d_ratio': '1.11',
#   'damage/round': '75.0',
#   'grenadedmg/round': '2.0',
#   'maps_played': '224',
#   'rounds_played': '5958',
#   'kills/round': '0.73',
#   'assists/round': '0.11',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.07',
#   'rating_1.0': '1.07'},
#  {'Name': 'Stewie2K',
#   'total_kills': '4934',
#   'headshot_%': '48.8%',
#   'total_deaths': '4581',
#   'k/d_ratio': '1.08',
#   'damage/round': '84.1',
#   'grenadedmg/round': '3.9',
#   'maps_played': '253',
#   'rounds_played': '6578',
#   'kills/round': '0.75',
#   'assists/round': '0.15',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.07'},
#  {'Name': 'MICHU',
#   'total_kills': '4203',
#   'headshot_%': '50.1%',
#   'total_deaths': '3842',
#   'k/d_ratio': '1.09',
#   'damage/round': '81.3',
#   'grenadedmg/round': '3.2',
#   'maps_played': '216',
#   'rounds_played': '5662',
#   'kills/round': '0.74',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.07'},
#  {'Name': 'REZ',
#   'total_kills': '4248',
#   'headshot_%': '49.1%',
#   'total_deaths': '3853',
#   'k/d_ratio': '1.10',
#   'damage/round': '78.6',
#   'grenadedmg/round': '2.9',
#   'maps_played': '220',
#   'rounds_played': '5870',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.06'},
#  {'Name': 'mou',
#   'total_kills': '3540',
#   'headshot_%': '28.9%',
#   'total_deaths': '3221',
#   'k/d_ratio': '1.10',
#   'damage/round': '76.1',
#   'grenadedmg/round': '3.6',
#   'maps_played': '183',
#   'rounds_played': '4846',
#   'kills/round': '0.73',
#   'assists/round': '0.12',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.06'},
#  {'Name': 'RUSH',
#   'total_kills': '4329',
#   'headshot_%': '46.2%',
#   'total_deaths': '3972',
#   'k/d_ratio': '1.09',
#   'damage/round': '77.2',
#   'grenadedmg/round': '3.2',
#   'maps_played': '237',
#   'rounds_played': '6002',
#   'kills/round': '0.72',
#   'assists/round': '0.15',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.12',
#   'savedteammates/round': '0.12',
#   'rating_1.0': '1.06'},
#  {'Name': 'fnx',
#   'total_kills': '4333',
#   'headshot_%': '51.3%',
#   'total_deaths': '3942',
#   'k/d_ratio': '1.10',
#   'damage/round': '82.1',
#   'grenadedmg/round': '6.2',
#   'maps_played': '232',
#   'rounds_played': '5997',
#   'kills/round': '0.72',
#   'assists/round': '0.16',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.06'},
#  {'Name': 'BARBARR',
#   'total_kills': '3604',
#   'headshot_%': '39.5%',
#   'total_deaths': '3340',
#   'k/d_ratio': '1.08',
#   'damage/round': '78.7',
#   'grenadedmg/round': '3.4',
#   'maps_played': '186',
#   'rounds_played': '4931',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.06'},
#  {'Name': 'Snax',
#   'total_kills': '4140',
#   'headshot_%': '28.7%',
#   'total_deaths': '3812',
#   'k/d_ratio': '1.09',
#   'damage/round': '77.7',
#   'grenadedmg/round': '3.8',
#   'maps_played': '218',
#   'rounds_played': '5746',
#   'kills/round': '0.72',
#   'assists/round': '0.12',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.05'},
#  {'Name': 'Skadoodle',
#   'total_kills': '4367',
#   'headshot_%': '23.2%',
#   'total_deaths': '3760',
#   'k/d_ratio': '1.16',
#   'damage/round': '68.4',
#   'grenadedmg/round': '2.5',
#   'maps_played': '253',
#   'rounds_played': '6578',
#   'kills/round': '0.66',
#   'assists/round': '0.10',
#   'death/round': '0.57',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.05'},
#  {'Name': 'JW',
#   'total_kills': '4134',
#   'headshot_%': '35.4%',
#   'total_deaths': '3860',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.3',
#   'grenadedmg/round': '4.3',
#   'maps_played': '222',
#   'rounds_played': '5741',
#   'kills/round': '0.72',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08',
#   'rating_1.0': '1.05'},
#  {'Name': 'mouz',
#   'total_kills': '4025',
#   'headshot_%': '48.9%',
#   'total_deaths': '3710',
#   'k/d_ratio': '1.08',
#   'damage/round': '77.2',
#   'grenadedmg/round': '2.1',
#   'maps_played': '216',
#   'rounds_played': '5662',
#   'kills/round': '0.71',
#   'assists/round': '0.13',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.05'},
#  {'Name': 'disco doplan',
#   'total_kills': '3843',
#   'headshot_%': '41.0%',
#   'total_deaths': '3581',
#   'k/d_ratio': '1.07',
#   'damage/round': '77.9',
#   'grenadedmg/round': '2.5',
#   'maps_played': '203',
#   'rounds_played': '5405',
#   'kills/round': '0.71',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09',
#   'rating_1.0': '1.04'},
#  {'Name': 'NAF',
#   'total_kills': '4215',
#   'headshot_%': '38.3%',
#   'total_deaths': '3901',
#   'k/d_ratio': '1.08',
#   'damage/round': '78.3',
#   'grenadedmg/round': '4.7',
#   'maps_played': '237',
#   'rounds_played': '6002',
#   'kills/round': '0.70',
#   'assists/round': '0.16',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.04'},
#  {'Name': 'suNny',
#   'total_kills': '4062',
#   'headshot_%': '43.0%',
#   'total_deaths': '3902',
#   'k/d_ratio': '1.04',
#   'damage/round': '82.5',
#   'grenadedmg/round': '4.6',
#   'maps_played': '204',
#   'rounds_played': '5532',
#   'kills/round': '0.73',
#   'assists/round': '0.16',
#   'death/round': '0.71',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10',
#   'rating_1.0': '1.04'},
#  {'Name': 'Pimp',
#   'total_kills': '4238',
#   'headshot_%': '48.2%',
#   'total_deaths': '3968',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.1',
#   'grenadedmg/round': '4.0',
#   'maps_played': '228',
#   'rounds_played': '5886',
#   'kills/round': '0.72',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11',
#   'rating_1.0': '1.04'}]

# %%
list_17_t50
# Out:
# [{'Name': 'XANTARES',
#   'total_kills': '5476',
#   'headshot_%': '52.5%',
#   'total_deaths': '4446',
#   'k/d_ratio': '1.23',
#   'damage/round': '96.6',
#   'grenadedmg/round': '3.2',
#   'maps_played': '244',
#   'rounds_played': '6362',
#   'kills/round': '0.86',
#   'assists/round': '0.17',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 's1mple',
#   'total_kills': '3998',
#   'headshot_%': '45.2%',
#   'total_deaths': '3091',
#   'k/d_ratio': '1.29',
#   'damage/round': '87.2',
#   'grenadedmg/round': '1.7',
#   'maps_played': '176',
#   'rounds_played': '4696',
#   'kills/round': '0.85',
#   'assists/round': '0.10',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.11'},
#  {'Name': 'coldzera',
#   'total_kills': '5071',
#   'headshot_%': '49.2%',
#   'total_deaths': '3703',
#   'k/d_ratio': '1.37',
#   'damage/round': '83.3',
#   'grenadedmg/round': '1.8',
#   'maps_played': '241',
#   'rounds_played': '6262',
#   'kills/round': '0.81',
#   'assists/round': '0.12',
#   'death/round': '0.59',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.09'},
#  {'Name': 'NiKo',
#   'total_kills': '5101',
#   'headshot_%': '52.5%',
#   'total_deaths': '4096',
#   'k/d_ratio': '1.25',
#   'damage/round': '85.9',
#   'grenadedmg/round': '3.4',
#   'maps_played': '246',
#   'rounds_played': '6372',
#   'kills/round': '0.80',
#   'assists/round': '0.13',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10'},
#  {'Name': 'fer',
#   'total_kills': '4904',
#   'headshot_%': '44.9%',
#   'total_deaths': '4207',
#   'k/d_ratio': '1.17',
#   'damage/round': '86.9',
#   'grenadedmg/round': '4.7',
#   'maps_played': '241',
#   'rounds_played': '6262',
#   'kills/round': '0.78',
#   'assists/round': '0.15',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08'},
#  {'Name': 'tabseN',
#   'total_kills': '4378',
#   'headshot_%': '52.2%',
#   'total_deaths': '3963',
#   'k/d_ratio': '1.10',
#   'damage/round': '89.5',
#   'grenadedmg/round': '6.6',
#   'maps_played': '207',
#   'rounds_played': '5482',
#   'kills/round': '0.80',
#   'assists/round': '0.16',
#   'death/round': '0.72',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'rain',
#   'total_kills': '4721',
#   'headshot_%': '59.5%',
#   'total_deaths': '4176',
#   'k/d_ratio': '1.13',
#   'damage/round': '85.5',
#   'grenadedmg/round': '3.1',
#   'maps_played': '239',
#   'rounds_played': '6218',
#   'kills/round': '0.76',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Twistzz',
#   'total_kills': '5122',
#   'headshot_%': '58.6%',
#   'total_deaths': '4205',
#   'k/d_ratio': '1.22',
#   'damage/round': '81.6',
#   'grenadedmg/round': '3.6',
#   'maps_played': '250',
#   'rounds_played': '6570',
#   'kills/round': '0.78',
#   'assists/round': '0.12',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.13'},
#  {'Name': 'oskar',
#   'total_kills': '4505',
#   'headshot_%': '30.5%',
#   'total_deaths': '3806',
#   'k/d_ratio': '1.18',
#   'damage/round': '81.2',
#   'grenadedmg/round': '2.5',
#   'maps_played': '220',
#   'rounds_played': '5789',
#   'kills/round': '0.78',
#   'assists/round': '0.11',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Calyx',
#   'total_kills': '4825',
#   'headshot_%': '53.4%',
#   'total_deaths': '3999',
#   'k/d_ratio': '1.21',
#   'damage/round': '79.4',
#   'grenadedmg/round': '3.1',
#   'maps_played': '246',
#   'rounds_played': '6431',
#   'kills/round': '0.75',
#   'assists/round': '0.12',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'EliGE',
#   'total_kills': '4896',
#   'headshot_%': '51.3%',
#   'total_deaths': '4336',
#   'k/d_ratio': '1.13',
#   'damage/round': '84.1',
#   'grenadedmg/round': '3.3',
#   'maps_played': '237',
#   'rounds_played': '6311',
#   'kills/round': '0.78',
#   'assists/round': '0.15',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.14'},
#  {'Name': 'MICHU',
#   'total_kills': '4615',
#   'headshot_%': '51.5%',
#   'total_deaths': '4027',
#   'k/d_ratio': '1.15',
#   'damage/round': '82.4',
#   'grenadedmg/round': '2.5',
#   'maps_played': '235',
#   'rounds_played': '5999',
#   'kills/round': '0.77',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'NAF',
#   'total_kills': '3785',
#   'headshot_%': '42.4%',
#   'total_deaths': '3353',
#   'k/d_ratio': '1.13',
#   'damage/round': '83.7',
#   'grenadedmg/round': '4.6',
#   'maps_played': '194',
#   'rounds_played': '5139',
#   'kills/round': '0.74',
#   'assists/round': '0.17',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'device',
#   'total_kills': '3780',
#   'headshot_%': '33.0%',
#   'total_deaths': '3146',
#   'k/d_ratio': '1.20',
#   'damage/round': '78.4',
#   'grenadedmg/round': '3.1',
#   'maps_played': '188',
#   'rounds_played': '4944',
#   'kills/round': '0.76',
#   'assists/round': '0.10',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Stewie2K',
#   'total_kills': '4485',
#   'headshot_%': '51.0%',
#   'total_deaths': '4154',
#   'k/d_ratio': '1.08',
#   'damage/round': '83.0',
#   'grenadedmg/round': '5.0',
#   'maps_played': '234',
#   'rounds_played': '6019',
#   'kills/round': '0.75',
#   'assists/round': '0.14',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.09'},
#  {'Name': 'JUGi',
#   'total_kills': '4216',
#   'headshot_%': '30.0%',
#   'total_deaths': '3428',
#   'k/d_ratio': '1.23',
#   'damage/round': '75.4',
#   'grenadedmg/round': '2.3',
#   'maps_played': '220',
#   'rounds_played': '5710',
#   'kills/round': '0.74',
#   'assists/round': '0.10',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11'},
#  {'Name': 'kennyS',
#   'total_kills': '4448',
#   'headshot_%': '30.4%',
#   'total_deaths': '3633',
#   'k/d_ratio': '1.22',
#   'damage/round': '75.0',
#   'grenadedmg/round': '2.9',
#   'maps_played': '218',
#   'rounds_played': '5814',
#   'kills/round': '0.77',
#   'assists/round': '0.09',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.13'},
#  {'Name': 'paz',
#   'total_kills': '4191',
#   'headshot_%': '50.0%',
#   'total_deaths': '3603',
#   'k/d_ratio': '1.16',
#   'damage/round': '77.9',
#   'grenadedmg/round': '1.8',
#   'maps_played': '215',
#   'rounds_played': '5600',
#   'kills/round': '0.75',
#   'assists/round': '0.12',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'suNny',
#   'total_kills': '4966',
#   'headshot_%': '47.3%',
#   'total_deaths': '4444',
#   'k/d_ratio': '1.12',
#   'damage/round': '83.1',
#   'grenadedmg/round': '3.9',
#   'maps_played': '245',
#   'rounds_played': '6465',
#   'kills/round': '0.77',
#   'assists/round': '0.14',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'autimatic',
#   'total_kills': '4426',
#   'headshot_%': '51.6%',
#   'total_deaths': '3986',
#   'k/d_ratio': '1.11',
#   'damage/round': '82.5',
#   'grenadedmg/round': '3.4',
#   'maps_played': '227',
#   'rounds_played': '5851',
#   'kills/round': '0.76',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.09'},
#  {'Name': 'nex',
#   'total_kills': '4086',
#   'headshot_%': '52.9%',
#   'total_deaths': '3663',
#   'k/d_ratio': '1.12',
#   'damage/round': '81.9',
#   'grenadedmg/round': '4.3',
#   'maps_played': '207',
#   'rounds_played': '5482',
#   'kills/round': '0.75',
#   'assists/round': '0.15',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.13'},
#  {'Name': 'ANGE1',
#   'total_kills': '4143',
#   'headshot_%': '55.6%',
#   'total_deaths': '4040',
#   'k/d_ratio': '1.03',
#   'damage/round': '86.0',
#   'grenadedmg/round': '4.7',
#   'maps_played': '215',
#   'rounds_played': '5574',
#   'kills/round': '0.74',
#   'assists/round': '0.16',
#   'death/round': '0.72',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.07'},
#  {'Name': 'k0nfig',
#   'total_kills': '3720',
#   'headshot_%': '52.4%',
#   'total_deaths': '3313',
#   'k/d_ratio': '1.12',
#   'damage/round': '80.1',
#   'grenadedmg/round': '1.2',
#   'maps_played': '184',
#   'rounds_played': '4942',
#   'kills/round': '0.75',
#   'assists/round': '0.12',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Hobbit',
#   'total_kills': '3684',
#   'headshot_%': '46.9%',
#   'total_deaths': '3251',
#   'k/d_ratio': '1.13',
#   'damage/round': '81.0',
#   'grenadedmg/round': '5.4',
#   'maps_played': '181',
#   'rounds_played': '4938',
#   'kills/round': '0.75',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'boltz',
#   'total_kills': '3602',
#   'headshot_%': '40.6%',
#   'total_deaths': '3323',
#   'k/d_ratio': '1.08',
#   'damage/round': '82.9',
#   'grenadedmg/round': '8.6',
#   'maps_played': '193',
#   'rounds_played': '5014',
#   'kills/round': '0.72',
#   'assists/round': '0.17',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'FalleN',
#   'total_kills': '4378',
#   'headshot_%': '30.8%',
#   'total_deaths': '3736',
#   'k/d_ratio': '1.17',
#   'damage/round': '73.2',
#   'grenadedmg/round': '2.9',
#   'maps_played': '241',
#   'rounds_played': '6262',
#   'kills/round': '0.70',
#   'assists/round': '0.11',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'draken',
#   'total_kills': '4182',
#   'headshot_%': '29.7%',
#   'total_deaths': '3606',
#   'k/d_ratio': '1.16',
#   'damage/round': '73.9',
#   'grenadedmg/round': '1.8',
#   'maps_played': '219',
#   'rounds_played': '5697',
#   'kills/round': '0.73',
#   'assists/round': '0.10',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'dupreeh',
#   'total_kills': '4133',
#   'headshot_%': '48.9%',
#   'total_deaths': '3770',
#   'k/d_ratio': '1.10',
#   'damage/round': '80.2',
#   'grenadedmg/round': '2.6',
#   'maps_played': '213',
#   'rounds_played': '5621',
#   'kills/round': '0.74',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Magisk',
#   'total_kills': '3658',
#   'headshot_%': '48.0%',
#   'total_deaths': '3308',
#   'k/d_ratio': '1.11',
#   'damage/round': '80.8',
#   'grenadedmg/round': '4.1',
#   'maps_played': '189',
#   'rounds_played': '5039',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'GuardiaN',
#   'total_kills': '3877',
#   'headshot_%': '28.0%',
#   'total_deaths': '3311',
#   'k/d_ratio': '1.17',
#   'damage/round': '73.6',
#   'grenadedmg/round': '2.8',
#   'maps_played': '207',
#   'rounds_played': '5325',
#   'kills/round': '0.73',
#   'assists/round': '0.09',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'CeRq',
#   'total_kills': '4206',
#   'headshot_%': '26.7%',
#   'total_deaths': '3711',
#   'k/d_ratio': '1.13',
#   'damage/round': '76.8',
#   'grenadedmg/round': '1.8',
#   'maps_played': '211',
#   'rounds_played': '5529',
#   'kills/round': '0.76',
#   'assists/round': '0.09',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'ropz',
#   'total_kills': '3725',
#   'headshot_%': '52.4%',
#   'total_deaths': '3291',
#   'k/d_ratio': '1.13',
#   'damage/round': '79.2',
#   'grenadedmg/round': '2.2',
#   'maps_played': '193',
#   'rounds_played': '5108',
#   'kills/round': '0.73',
#   'assists/round': '0.12',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Lekr0',
#   'total_kills': '3478',
#   'headshot_%': '51.8%',
#   'total_deaths': '3212',
#   'k/d_ratio': '1.08',
#   'damage/round': '80.3',
#   'grenadedmg/round': '3.4',
#   'maps_played': '178',
#   'rounds_played': '4765',
#   'kills/round': '0.73',
#   'assists/round': '0.15',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'valde',
#   'total_kills': '3393',
#   'headshot_%': '43.2%',
#   'total_deaths': '3169',
#   'k/d_ratio': '1.07',
#   'damage/round': '80.4',
#   'grenadedmg/round': '4.1',
#   'maps_played': '175',
#   'rounds_played': '4674',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Rickeh',
#   'total_kills': '3433',
#   'headshot_%': '39.5%',
#   'total_deaths': '3202',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.6',
#   'grenadedmg/round': '4.6',
#   'maps_played': '179',
#   'rounds_played': '4900',
#   'kills/round': '0.70',
#   'assists/round': '0.14',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'olofmeister',
#   'total_kills': '4608',
#   'headshot_%': '48.3%',
#   'total_deaths': '4136',
#   'k/d_ratio': '1.11',
#   'damage/round': '78.6',
#   'grenadedmg/round': '4.8',
#   'maps_played': '244',
#   'rounds_played': '6285',
#   'kills/round': '0.73',
#   'assists/round': '0.12',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'AdreN',
#   'total_kills': '3581',
#   'headshot_%': '48.2%',
#   'total_deaths': '3427',
#   'k/d_ratio': '1.04',
#   'damage/round': '82.4',
#   'grenadedmg/round': '5.5',
#   'maps_played': '180',
#   'rounds_played': '4908',
#   'kills/round': '0.73',
#   'assists/round': '0.16',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'ScreaM',
#   'total_kills': '4620',
#   'headshot_%': '64.7%',
#   'total_deaths': '4380',
#   'k/d_ratio': '1.05',
#   'damage/round': '79.7',
#   'grenadedmg/round': '2.8',
#   'maps_played': '245',
#   'rounds_played': '6363',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.12'},
#  {'Name': 'Ethan',
#   'total_kills': '3713',
#   'headshot_%': '50.0%',
#   'total_deaths': '3584',
#   'k/d_ratio': '1.04',
#   'damage/round': '81.2',
#   'grenadedmg/round': '3.1',
#   'maps_played': '185',
#   'rounds_played': '5040',
#   'kills/round': '0.74',
#   'assists/round': '0.14',
#   'death/round': '0.71',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.11'},
#  {'Name': 'twist',
#   'total_kills': '3220',
#   'headshot_%': '41.1%',
#   'total_deaths': '3056',
#   'k/d_ratio': '1.05',
#   'damage/round': '80.5',
#   'grenadedmg/round': '3.5',
#   'maps_played': '166',
#   'rounds_played': '4385',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'REZ',
#   'total_kills': '3671',
#   'headshot_%': '49.2%',
#   'total_deaths': '3513',
#   'k/d_ratio': '1.04',
#   'damage/round': '78.5',
#   'grenadedmg/round': '3.2',
#   'maps_played': '199',
#   'rounds_played': '5233',
#   'kills/round': '0.70',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.10'},
#  {'Name': 'ShahZaM',
#   'total_kills': '3546',
#   'headshot_%': '36.2%',
#   'total_deaths': '3198',
#   'k/d_ratio': '1.11',
#   'damage/round': '74.0',
#   'grenadedmg/round': '2.0',
#   'maps_played': '183',
#   'rounds_played': '4848',
#   'kills/round': '0.73',
#   'assists/round': '0.09',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'JW',
#   'total_kills': '4187',
#   'headshot_%': '36.1%',
#   'total_deaths': '3910',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.4',
#   'grenadedmg/round': '4.3',
#   'maps_played': '216',
#   'rounds_played': '5684',
#   'kills/round': '0.74',
#   'assists/round': '0.13',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'cajunb',
#   'total_kills': '3461',
#   'headshot_%': '32.4%',
#   'total_deaths': '3005',
#   'k/d_ratio': '1.15',
#   'damage/round': '72.5',
#   'grenadedmg/round': '2.2',
#   'maps_played': '184',
#   'rounds_played': '4942',
#   'kills/round': '0.70',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Brehze',
#   'total_kills': '3270',
#   'headshot_%': '50.9%',
#   'total_deaths': '3148',
#   'k/d_ratio': '1.04',
#   'damage/round': '79.9',
#   'grenadedmg/round': '2.5',
#   'maps_played': '166',
#   'rounds_played': '4410',
#   'kills/round': '0.74',
#   'assists/round': '0.12',
#   'death/round': '0.71',
#   'savedbyteammate/round': '0.12',
#   'savedteammates/round': '0.13'},
#  {'Name': 'mixwell',
#   'total_kills': '3602',
#   'headshot_%': '37.8%',
#   'total_deaths': '3432',
#   'k/d_ratio': '1.05',
#   'damage/round': '75.9',
#   'grenadedmg/round': '5.2',
#   'maps_played': '195',
#   'rounds_played': '5096',
#   'kills/round': '0.71',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'jks',
#   'total_kills': '3750',
#   'headshot_%': '54.1%',
#   'total_deaths': '3444',
#   'k/d_ratio': '1.09',
#   'damage/round': '77.4',
#   'grenadedmg/round': '4.2',
#   'maps_played': '201',
#   'rounds_played': '5324',
#   'kills/round': '0.70',
#   'assists/round': '0.12',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'shox',
#   'total_kills': '3966',
#   'headshot_%': '47.3%',
#   'total_deaths': '3673',
#   'k/d_ratio': '1.08',
#   'damage/round': '75.2',
#   'grenadedmg/round': '2.4',
#   'maps_played': '211',
#   'rounds_played': '5608',
#   'kills/round': '0.71',
#   'assists/round': '0.11',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'tarik',
#   'total_kills': '3894',
#   'headshot_%': '38.8%',
#   'total_deaths': '3779',
#   'k/d_ratio': '1.03',
#   'damage/round': '77.8',
#   'grenadedmg/round': '2.6',
#   'maps_played': '215',
#   'rounds_played': '5520',
#   'kills/round': '0.71',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Furlan',
#   'total_kills': '4112',
#   'headshot_%': '55.2%',
#   'total_deaths': '4007',
#   'k/d_ratio': '1.03',
#   'damage/round': '78.2',
#   'grenadedmg/round': '3.9',
#   'maps_played': '233',
#   'rounds_played': '5957',
#   'kills/round': '0.69',
#   'assists/round': '0.15',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.09'}]

# %%
list_18_t50
# Out:
# [{'Name': 's1mple',
#   'total_kills': '5761',
#   'headshot_%': '40.2%',
#   'total_deaths': '3854',
#   'k/d_ratio': '1.49',
#   'damage/round': '87.2',
#   'grenadedmg/round': '2.3',
#   'maps_played': '251',
#   'rounds_played': '6545',
#   'kills/round': '0.88',
#   'assists/round': '0.10',
#   'death/round': '0.59',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.12'},
#  {'Name': 'woxic',
#   'total_kills': '4490',
#   'headshot_%': '33.7%',
#   'total_deaths': '3452',
#   'k/d_ratio': '1.30',
#   'damage/round': '82.7',
#   'grenadedmg/round': '1.7',
#   'maps_played': '211',
#   'rounds_played': '5508',
#   'kills/round': '0.82',
#   'assists/round': '0.10',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'XANTARES',
#   'total_kills': '4323',
#   'headshot_%': '55.7%',
#   'total_deaths': '3842',
#   'k/d_ratio': '1.13',
#   'damage/round': '92.2',
#   'grenadedmg/round': '4.1',
#   'maps_played': '205',
#   'rounds_played': '5343',
#   'kills/round': '0.81',
#   'assists/round': '0.16',
#   'death/round': '0.72',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'device',
#   'total_kills': '5246',
#   'headshot_%': '33.2%',
#   'total_deaths': '3977',
#   'k/d_ratio': '1.32',
#   'damage/round': '81.4',
#   'grenadedmg/round': '5.2',
#   'maps_played': '255',
#   'rounds_played': '6642',
#   'kills/round': '0.79',
#   'assists/round': '0.12',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.08'},
#  {'Name': 'NiKo',
#   'total_kills': '5294',
#   'headshot_%': '48.7%',
#   'total_deaths': '4255',
#   'k/d_ratio': '1.24',
#   'damage/round': '84.8',
#   'grenadedmg/round': '3.7',
#   'maps_played': '252',
#   'rounds_played': '6628',
#   'kills/round': '0.80',
#   'assists/round': '0.13',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Ethan',
#   'total_kills': '4883',
#   'headshot_%': '48.8%',
#   'total_deaths': '4203',
#   'k/d_ratio': '1.16',
#   'damage/round': '85.8',
#   'grenadedmg/round': '4.9',
#   'maps_played': '248',
#   'rounds_played': '6426',
#   'kills/round': '0.76',
#   'assists/round': '0.16',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'electronic',
#   'total_kills': '4887',
#   'headshot_%': '50.1%',
#   'total_deaths': '4031',
#   'k/d_ratio': '1.21',
#   'damage/round': '83.7',
#   'grenadedmg/round': '4.5',
#   'maps_played': '247',
#   'rounds_played': '6443',
#   'kills/round': '0.76',
#   'assists/round': '0.14',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Brehze',
#   'total_kills': '4911',
#   'headshot_%': '52.7%',
#   'total_deaths': '4090',
#   'k/d_ratio': '1.20',
#   'damage/round': '80.3',
#   'grenadedmg/round': '2.6',
#   'maps_played': '248',
#   'rounds_played': '6426',
#   'kills/round': '0.76',
#   'assists/round': '0.12',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'CeRq',
#   'total_kills': '4742',
#   'headshot_%': '28.4%',
#   'total_deaths': '3860',
#   'k/d_ratio': '1.23',
#   'damage/round': '74.6',
#   'grenadedmg/round': '2.4',
#   'maps_played': '248',
#   'rounds_played': '6426',
#   'kills/round': '0.74',
#   'assists/round': '0.10',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'NAF',
#   'total_kills': '5113',
#   'headshot_%': '42.4%',
#   'total_deaths': '4372',
#   'k/d_ratio': '1.17',
#   'damage/round': '82.7',
#   'grenadedmg/round': '6.2',
#   'maps_played': '273',
#   'rounds_played': '7022',
#   'kills/round': '0.73',
#   'assists/round': '0.16',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'coldzera',
#   'total_kills': '4980',
#   'headshot_%': '48.3%',
#   'total_deaths': '3938',
#   'k/d_ratio': '1.26',
#   'damage/round': '79.3',
#   'grenadedmg/round': '2.3',
#   'maps_played': '243',
#   'rounds_played': '6460',
#   'kills/round': '0.77',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.10'},
#  {'Name': 'dupreeh',
#   'total_kills': '4877',
#   'headshot_%': '49.7%',
#   'total_deaths': '4184',
#   'k/d_ratio': '1.17',
#   'damage/round': '79.6',
#   'grenadedmg/round': '3.3',
#   'maps_played': '255',
#   'rounds_played': '6642',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.08'},
#  {'Name': 'rallen',
#   'total_kills': '4320',
#   'headshot_%': '45.6%',
#   'total_deaths': '3901',
#   'k/d_ratio': '1.11',
#   'damage/round': '85.8',
#   'grenadedmg/round': '8.7',
#   'maps_played': '217',
#   'rounds_played': '5873',
#   'kills/round': '0.74',
#   'assists/round': '0.17',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Magisk',
#   'total_kills': '4684',
#   'headshot_%': '49.5%',
#   'total_deaths': '3979',
#   'k/d_ratio': '1.18',
#   'damage/round': '78.9',
#   'grenadedmg/round': '6.3',
#   'maps_played': '251',
#   'rounds_played': '6548',
#   'kills/round': '0.72',
#   'assists/round': '0.16',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10'},
#  {'Name': 'syrsoN',
#   'total_kills': '4019',
#   'headshot_%': '24.5%',
#   'total_deaths': '3264',
#   'k/d_ratio': '1.23',
#   'damage/round': '76.6',
#   'grenadedmg/round': '1.6',
#   'maps_played': '195',
#   'rounds_played': '5215',
#   'kills/round': '0.77',
#   'assists/round': '0.08',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.10'},
#  {'Name': 'valde',
#   'total_kills': '5228',
#   'headshot_%': '45.5%',
#   'total_deaths': '4504',
#   'k/d_ratio': '1.16',
#   'damage/round': '81.4',
#   'grenadedmg/round': '4.5',
#   'maps_played': '266',
#   'rounds_played': '6980',
#   'kills/round': '0.75',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Twistzz',
#   'total_kills': '5148',
#   'headshot_%': '61.8%',
#   'total_deaths': '4307',
#   'k/d_ratio': '1.20',
#   'damage/round': '76.0',
#   'grenadedmg/round': '3.4',
#   'maps_played': '272',
#   'rounds_played': '7027',
#   'kills/round': '0.73',
#   'assists/round': '0.11',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'EspiranTo',
#   'total_kills': '3792',
#   'headshot_%': '59.6%',
#   'total_deaths': '3445',
#   'k/d_ratio': '1.10',
#   'damage/round': '79.4',
#   'grenadedmg/round': '2.7',
#   'maps_played': '188',
#   'rounds_played': '4895',
#   'kills/round': '0.77',
#   'assists/round': '0.11',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'nexa',
#   'total_kills': '3599',
#   'headshot_%': '51.1%',
#   'total_deaths': '3169',
#   'k/d_ratio': '1.14',
#   'damage/round': '80.3',
#   'grenadedmg/round': '4.1',
#   'maps_played': '189',
#   'rounds_played': '4924',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'NaToSaphiX',
#   'total_kills': '3956',
#   'headshot_%': '34.5%',
#   'total_deaths': '3280',
#   'k/d_ratio': '1.21',
#   'damage/round': '72.9',
#   'grenadedmg/round': '2.2',
#   'maps_played': '207',
#   'rounds_played': '5507',
#   'kills/round': '0.72',
#   'assists/round': '0.10',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Jame',
#   'total_kills': '3467',
#   'headshot_%': '26.4%',
#   'total_deaths': '2891',
#   'k/d_ratio': '1.20',
#   'damage/round': '71.6',
#   'grenadedmg/round': '3.3',
#   'maps_played': '193',
#   'rounds_played': '5005',
#   'kills/round': '0.69',
#   'assists/round': '0.10',
#   'death/round': '0.58',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Xyp9x',
#   'total_kills': '4532',
#   'headshot_%': '39.7%',
#   'total_deaths': '3839',
#   'k/d_ratio': '1.18',
#   'damage/round': '76.3',
#   'grenadedmg/round': '6.3',
#   'maps_played': '255',
#   'rounds_played': '6642',
#   'kills/round': '0.68',
#   'assists/round': '0.15',
#   'death/round': '0.58',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'oskar',
#   'total_kills': '5249',
#   'headshot_%': '29.4%',
#   'total_deaths': '4559',
#   'k/d_ratio': '1.15',
#   'damage/round': '76.7',
#   'grenadedmg/round': '3.0',
#   'maps_played': '271',
#   'rounds_played': '7103',
#   'kills/round': '0.74',
#   'assists/round': '0.09',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'EliGE',
#   'total_kills': '5215',
#   'headshot_%': '46.5%',
#   'total_deaths': '4869',
#   'k/d_ratio': '1.07',
#   'damage/round': '81.3',
#   'grenadedmg/round': '4.4',
#   'maps_played': '278',
#   'rounds_played': '7163',
#   'kills/round': '0.73',
#   'assists/round': '0.16',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'qikert',
#   'total_kills': '3931',
#   'headshot_%': '54.4%',
#   'total_deaths': '3576',
#   'k/d_ratio': '1.10',
#   'damage/round': '80.0',
#   'grenadedmg/round': '3.8',
#   'maps_played': '210',
#   'rounds_played': '5413',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'autimatic',
#   'total_kills': '3848',
#   'headshot_%': '43.6%',
#   'total_deaths': '3354',
#   'k/d_ratio': '1.15',
#   'damage/round': '78.5',
#   'grenadedmg/round': '3.9',
#   'maps_played': '194',
#   'rounds_played': '5137',
#   'kills/round': '0.75',
#   'assists/round': '0.12',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'k0nfig',
#   'total_kills': '4163',
#   'headshot_%': '57.0%',
#   'total_deaths': '3965',
#   'k/d_ratio': '1.05',
#   'damage/round': '82.3',
#   'grenadedmg/round': '3.1',
#   'maps_played': '213',
#   'rounds_played': '5568',
#   'kills/round': '0.75',
#   'assists/round': '0.14',
#   'death/round': '0.71',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'ISSAA',
#   'total_kills': '4166',
#   'headshot_%': '58.5%',
#   'total_deaths': '3672',
#   'k/d_ratio': '1.13',
#   'damage/round': '76.8',
#   'grenadedmg/round': '3.2',
#   'maps_played': '217',
#   'rounds_played': '5656',
#   'kills/round': '0.74',
#   'assists/round': '0.11',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'gla1ve',
#   'total_kills': '4575',
#   'headshot_%': '45.8%',
#   'total_deaths': '4143',
#   'k/d_ratio': '1.10',
#   'damage/round': '77.2',
#   'grenadedmg/round': '7.5',
#   'maps_played': '255',
#   'rounds_played': '6642',
#   'kills/round': '0.69',
#   'assists/round': '0.16',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08'},
#  {'Name': 'fer',
#   'total_kills': '4487',
#   'headshot_%': '47.8%',
#   'total_deaths': '4333',
#   'k/d_ratio': '1.04',
#   'damage/round': '80.8',
#   'grenadedmg/round': '5.2',
#   'maps_played': '238',
#   'rounds_played': '6337',
#   'kills/round': '0.71',
#   'assists/round': '0.15',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08'},
#  {'Name': 'suNny',
#   'total_kills': '5402',
#   'headshot_%': '49.4%',
#   'total_deaths': '4974',
#   'k/d_ratio': '1.09',
#   'damage/round': '81.3',
#   'grenadedmg/round': '4.9',
#   'maps_played': '282',
#   'rounds_played': '7378',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'JUGi',
#   'total_kills': '3978',
#   'headshot_%': '27.3%',
#   'total_deaths': '3460',
#   'k/d_ratio': '1.15',
#   'damage/round': '71.7',
#   'grenadedmg/round': '2.2',
#   'maps_played': '220',
#   'rounds_played': '5750',
#   'kills/round': '0.69',
#   'assists/round': '0.10',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Kjaerbye',
#   'total_kills': '5004',
#   'headshot_%': '54.1%',
#   'total_deaths': '4662',
#   'k/d_ratio': '1.07',
#   'damage/round': '79.3',
#   'grenadedmg/round': '4.6',
#   'maps_played': '267',
#   'rounds_played': '6990',
#   'kills/round': '0.72',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'es3tag',
#   'total_kills': '4013',
#   'headshot_%': '36.0%',
#   'total_deaths': '3824',
#   'k/d_ratio': '1.05',
#   'damage/round': '78.1',
#   'grenadedmg/round': '3.9',
#   'maps_played': '218',
#   'rounds_played': '5683',
#   'kills/round': '0.71',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.11'},
#  {'Name': 'GuardiaN',
#   'total_kills': '4742',
#   'headshot_%': '27.2%',
#   'total_deaths': '4103',
#   'k/d_ratio': '1.16',
#   'damage/round': '71.7',
#   'grenadedmg/round': '2.7',
#   'maps_played': '252',
#   'rounds_played': '6628',
#   'kills/round': '0.72',
#   'assists/round': '0.08',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'SHiPZ',
#   'total_kills': '5037',
#   'headshot_%': '50.1%',
#   'total_deaths': '4731',
#   'k/d_ratio': '1.06',
#   'damage/round': '77.8',
#   'grenadedmg/round': '3.1',
#   'maps_played': '259',
#   'rounds_played': '6843',
#   'kills/round': '0.74',
#   'assists/round': '0.12',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.11'},
#  {'Name': 'KRIMZ',
#   'total_kills': '3944',
#   'headshot_%': '41.8%',
#   'total_deaths': '3655',
#   'k/d_ratio': '1.08',
#   'damage/round': '81.5',
#   'grenadedmg/round': '3.1',
#   'maps_played': '202',
#   'rounds_played': '5383',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.10'},
#  {'Name': 'jkaem',
#   'total_kills': '3920',
#   'headshot_%': '52.8%',
#   'total_deaths': '3825',
#   'k/d_ratio': '1.02',
#   'damage/round': '79.2',
#   'grenadedmg/round': '3.8',
#   'maps_played': '206',
#   'rounds_played': '5512',
#   'kills/round': '0.71',
#   'assists/round': '0.15',
#   'death/round': '0.69',
#   'savedbyteammate/round': '0.12',
#   'savedteammates/round': '0.12'},
#  {'Name': 'ropz',
#   'total_kills': '5123',
#   'headshot_%': '52.3%',
#   'total_deaths': '4492',
#   'k/d_ratio': '1.14',
#   'damage/round': '75.2',
#   'grenadedmg/round': '2.3',
#   'maps_played': '282',
#   'rounds_played': '7378',
#   'kills/round': '0.69',
#   'assists/round': '0.11',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.09'},
#  {'Name': 'buster',
#   'total_kills': '3705',
#   'headshot_%': '47.0%',
#   'total_deaths': '3362',
#   'k/d_ratio': '1.10',
#   'damage/round': '73.8',
#   'grenadedmg/round': '2.1',
#   'maps_played': '208',
#   'rounds_played': '5369',
#   'kills/round': '0.69',
#   'assists/round': '0.12',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.08'},
#  {'Name': 'kennyS',
#   'total_kills': '3822',
#   'headshot_%': '31.8%',
#   'total_deaths': '3416',
#   'k/d_ratio': '1.12',
#   'damage/round': '74.8',
#   'grenadedmg/round': '3.2',
#   'maps_played': '196',
#   'rounds_played': '5175',
#   'kills/round': '0.74',
#   'assists/round': '0.09',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Calyx',
#   'total_kills': '3742',
#   'headshot_%': '58.7%',
#   'total_deaths': '3361',
#   'k/d_ratio': '1.11',
#   'damage/round': '75.7',
#   'grenadedmg/round': '3.6',
#   'maps_played': '200',
#   'rounds_played': '5229',
#   'kills/round': '0.72',
#   'assists/round': '0.11',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'rain',
#   'total_kills': '4578',
#   'headshot_%': '54.6%',
#   'total_deaths': '4525',
#   'k/d_ratio': '1.01',
#   'damage/round': '78.8',
#   'grenadedmg/round': '3.5',
#   'maps_played': '252',
#   'rounds_played': '6628',
#   'kills/round': '0.69',
#   'assists/round': '0.15',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.11',
#   'savedteammates/round': '0.09'},
#  {'Name': 'twist',
#   'total_kills': '4759',
#   'headshot_%': '36.7%',
#   'total_deaths': '4442',
#   'k/d_ratio': '1.07',
#   'damage/round': '75.9',
#   'grenadedmg/round': '3.7',
#   'maps_played': '252',
#   'rounds_played': '6732',
#   'kills/round': '0.71',
#   'assists/round': '0.12',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'jks',
#   'total_kills': '4104',
#   'headshot_%': '53.6%',
#   'total_deaths': '3767',
#   'k/d_ratio': '1.09',
#   'damage/round': '76.2',
#   'grenadedmg/round': '5.3',
#   'maps_played': '223',
#   'rounds_played': '5935',
#   'kills/round': '0.69',
#   'assists/round': '0.12',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10'},
#  {'Name': 'tarik',
#   'total_kills': '4231',
#   'headshot_%': '37.5%',
#   'total_deaths': '4083',
#   'k/d_ratio': '1.04',
#   'damage/round': '77.5',
#   'grenadedmg/round': '2.7',
#   'maps_played': '233',
#   'rounds_played': '6081',
#   'kills/round': '0.70',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'MINISE',
#   'total_kills': '4427',
#   'headshot_%': '37.3%',
#   'total_deaths': '4139',
#   'k/d_ratio': '1.07',
#   'damage/round': '75.6',
#   'grenadedmg/round': '5.3',
#   'maps_played': '228',
#   'rounds_played': '6205',
#   'kills/round': '0.71',
#   'assists/round': '0.11',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.07'},
#  {'Name': 'mouz',
#   'total_kills': '4082',
#   'headshot_%': '51.7%',
#   'total_deaths': '3842',
#   'k/d_ratio': '1.06',
#   'damage/round': '75.1',
#   'grenadedmg/round': '3.1',
#   'maps_played': '217',
#   'rounds_played': '5873',
#   'kills/round': '0.70',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'f0rest',
#   'total_kills': '3929',
#   'headshot_%': '55.1%',
#   'total_deaths': '3597',
#   'k/d_ratio': '1.09',
#   'damage/round': '75.3',
#   'grenadedmg/round': '3.6',
#   'maps_played': '211',
#   'rounds_played': '5542',
#   'kills/round': '0.71',
#   'assists/round': '0.11',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'REZ',
#   'total_kills': '3826',
#   'headshot_%': '49.8%',
#   'total_deaths': '3713',
#   'k/d_ratio': '1.03',
#   'damage/round': '77.8',
#   'grenadedmg/round': '4.1',
#   'maps_played': '211',
#   'rounds_played': '5542',
#   'kills/round': '0.69',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'}]

# %%
list_19_t50
# Out:
# [{'Name': 'ZywOo',
#   'total_kills': '5352',
#   'headshot_%': '39.2%',
#   'total_deaths': '3898',
#   'k/d_ratio': '1.37',
#   'damage/round': '85.4',
#   'grenadedmg/round': '3.7',
#   'maps_played': '246',
#   'rounds_played': '6472',
#   'kills/round': '0.83',
#   'assists/round': '0.12',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Jame',
#   'total_kills': '5458',
#   'headshot_%': '25.5%',
#   'total_deaths': '3948',
#   'k/d_ratio': '1.38',
#   'damage/round': '77.3',
#   'grenadedmg/round': '4.1',
#   'maps_played': '267',
#   'rounds_played': '7239',
#   'kills/round': '0.75',
#   'assists/round': '0.09',
#   'death/round': '0.55',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.09'},
#  {'Name': 'huNter-',
#   'total_kills': '5405',
#   'headshot_%': '53.5%',
#   'total_deaths': '4563',
#   'k/d_ratio': '1.18',
#   'damage/round': '86.2',
#   'grenadedmg/round': '5.9',
#   'maps_played': '258',
#   'rounds_played': '6909',
#   'kills/round': '0.78',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'EliGE',
#   'total_kills': '4404',
#   'headshot_%': '51.0%',
#   'total_deaths': '3716',
#   'k/d_ratio': '1.19',
#   'damage/round': '85.4',
#   'grenadedmg/round': '4.7',
#   'maps_played': '214',
#   'rounds_played': '5661',
#   'kills/round': '0.78',
#   'assists/round': '0.14',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'ropz',
#   'total_kills': '3839',
#   'headshot_%': '50.3%',
#   'total_deaths': '3007',
#   'k/d_ratio': '1.28',
#   'damage/round': '80.5',
#   'grenadedmg/round': '2.9',
#   'maps_played': '191',
#   'rounds_played': '5070',
#   'kills/round': '0.76',
#   'assists/round': '0.11',
#   'death/round': '0.59',
#   'savedbyteammate/round': '0.06',
#   'savedteammates/round': '0.10'},
#  {'Name': 'xsepower',
#   'total_kills': '5560',
#   'headshot_%': '24.8%',
#   'total_deaths': '4360',
#   'k/d_ratio': '1.28',
#   'damage/round': '74.2',
#   'grenadedmg/round': '2.0',
#   'maps_played': '277',
#   'rounds_played': '7497',
#   'kills/round': '0.74',
#   'assists/round': '0.08',
#   'death/round': '0.58',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.08'},
#  {'Name': 'KSCERATO',
#   'total_kills': '4385',
#   'headshot_%': '49.3%',
#   'total_deaths': '3448',
#   'k/d_ratio': '1.27',
#   'damage/round': '79.4',
#   'grenadedmg/round': '4.8',
#   'maps_played': '224',
#   'rounds_played': '5934',
#   'kills/round': '0.74',
#   'assists/round': '0.12',
#   'death/round': '0.58',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11'},
#  {'Name': 'NAF',
#   'total_kills': '4088',
#   'headshot_%': '41.2%',
#   'total_deaths': '3488',
#   'k/d_ratio': '1.17',
#   'damage/round': '82.1',
#   'grenadedmg/round': '6.3',
#   'maps_played': '214',
#   'rounds_played': '5661',
#   'kills/round': '0.72',
#   'assists/round': '0.15',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'poizon',
#   'total_kills': '3981',
#   'headshot_%': '34.3%',
#   'total_deaths': '3402',
#   'k/d_ratio': '1.17',
#   'damage/round': '81.2',
#   'grenadedmg/round': '3.5',
#   'maps_played': '195',
#   'rounds_played': '5195',
#   'kills/round': '0.77',
#   'assists/round': '0.12',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11'},
#  {'Name': 'Brehze',
#   'total_kills': '4278',
#   'headshot_%': '50.9%',
#   'total_deaths': '3629',
#   'k/d_ratio': '1.18',
#   'damage/round': '80.6',
#   'grenadedmg/round': '2.3',
#   'maps_played': '209',
#   'rounds_played': '5549',
#   'kills/round': '0.77',
#   'assists/round': '0.12',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'ZOREE',
#   'total_kills': '4173',
#   'headshot_%': '29.5%',
#   'total_deaths': '3350',
#   'k/d_ratio': '1.25',
#   'damage/round': '76.0',
#   'grenadedmg/round': '3.6',
#   'maps_played': '203',
#   'rounds_played': '5470',
#   'kills/round': '0.76',
#   'assists/round': '0.08',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.09'},
#  {'Name': 'frozen',
#   'total_kills': '4429',
#   'headshot_%': '53.0%',
#   'total_deaths': '3778',
#   'k/d_ratio': '1.17',
#   'damage/round': '80.0',
#   'grenadedmg/round': '5.3',
#   'maps_played': '231',
#   'rounds_played': '6079',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'woxic',
#   'total_kills': '3740',
#   'headshot_%': '34.6%',
#   'total_deaths': '3127',
#   'k/d_ratio': '1.20',
#   'damage/round': '76.2',
#   'grenadedmg/round': '2.1',
#   'maps_played': '192',
#   'rounds_played': '5091',
#   'kills/round': '0.73',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Bubzkji',
#   'total_kills': '4070',
#   'headshot_%': '49.4%',
#   'total_deaths': '3593',
#   'k/d_ratio': '1.13',
#   'damage/round': '83.7',
#   'grenadedmg/round': '5.6',
#   'maps_played': '201',
#   'rounds_played': '5390',
#   'kills/round': '0.76',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'syrsoN',
#   'total_kills': '4767',
#   'headshot_%': '25.0%',
#   'total_deaths': '4068',
#   'k/d_ratio': '1.17',
#   'damage/round': '74.1',
#   'grenadedmg/round': '2.0',
#   'maps_played': '242',
#   'rounds_played': '6442',
#   'kills/round': '0.74',
#   'assists/round': '0.09',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'nexa',
#   'total_kills': '5017',
#   'headshot_%': '51.2%',
#   'total_deaths': '4332',
#   'k/d_ratio': '1.16',
#   'damage/round': '78.9',
#   'grenadedmg/round': '4.9',
#   'maps_played': '258',
#   'rounds_played': '6909',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'tabseN',
#   'total_kills': '3438',
#   'headshot_%': '42.2%',
#   'total_deaths': '3164',
#   'k/d_ratio': '1.09',
#   'damage/round': '82.8',
#   'grenadedmg/round': '6.2',
#   'maps_played': '174',
#   'rounds_played': '4639',
#   'kills/round': '0.74',
#   'assists/round': '0.14',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'yuurih',
#   'total_kills': '4318',
#   'headshot_%': '46.2%',
#   'total_deaths': '3875',
#   'k/d_ratio': '1.11',
#   'damage/round': '81.8',
#   'grenadedmg/round': '4.2',
#   'maps_played': '224',
#   'rounds_played': '5934',
#   'kills/round': '0.73',
#   'assists/round': '0.14',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'somedieyoung',
#   'total_kills': '3755',
#   'headshot_%': '49.4%',
#   'total_deaths': '3313',
#   'k/d_ratio': '1.13',
#   'damage/round': '80.4',
#   'grenadedmg/round': '4.6',
#   'maps_played': '189',
#   'rounds_played': '5129',
#   'kills/round': '0.73',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'kennyS',
#   'total_kills': '4632',
#   'headshot_%': '32.1%',
#   'total_deaths': '3973',
#   'k/d_ratio': '1.17',
#   'damage/round': '75.5',
#   'grenadedmg/round': '3.5',
#   'maps_played': '235',
#   'rounds_played': '6372',
#   'kills/round': '0.73',
#   'assists/round': '0.11',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Twistzz',
#   'total_kills': '4005',
#   'headshot_%': '66.1%',
#   'total_deaths': '3372',
#   'k/d_ratio': '1.19',
#   'damage/round': '73.7',
#   'grenadedmg/round': '3.7',
#   'maps_played': '214',
#   'rounds_played': '5661',
#   'kills/round': '0.71',
#   'assists/round': '0.11',
#   'death/round': '0.60',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.12'},
#  {'Name': 'acoR',
#   'total_kills': '3851',
#   'headshot_%': '28.8%',
#   'total_deaths': '3266',
#   'k/d_ratio': '1.18',
#   'damage/round': '73.7',
#   'grenadedmg/round': '3.3',
#   'maps_played': '199',
#   'rounds_played': '5344',
#   'kills/round': '0.72',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'CeRq',
#   'total_kills': '4037',
#   'headshot_%': '27.8%',
#   'total_deaths': '3462',
#   'k/d_ratio': '1.17',
#   'damage/round': '72.3',
#   'grenadedmg/round': '2.2',
#   'maps_played': '213',
#   'rounds_played': '5646',
#   'kills/round': '0.72',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'FREDDyFROG',
#   'total_kills': '3912',
#   'headshot_%': '42.2%',
#   'total_deaths': '3542',
#   'k/d_ratio': '1.10',
#   'damage/round': '79.5',
#   'grenadedmg/round': '4.0',
#   'maps_played': '201',
#   'rounds_played': '5450',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Ethan',
#   'total_kills': '3947',
#   'headshot_%': '48.1%',
#   'total_deaths': '3744',
#   'k/d_ratio': '1.05',
#   'damage/round': '80.7',
#   'grenadedmg/round': '4.9',
#   'maps_played': '213',
#   'rounds_played': '5646',
#   'kills/round': '0.70',
#   'assists/round': '0.16',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.11'},
#  {'Name': 'qikert',
#   'total_kills': '5113',
#   'headshot_%': '55.6%',
#   'total_deaths': '4684',
#   'k/d_ratio': '1.09',
#   'damage/round': '78.5',
#   'grenadedmg/round': '5.0',
#   'maps_played': '267',
#   'rounds_played': '7239',
#   'kills/round': '0.71',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'Brollan',
#   'total_kills': '3887',
#   'headshot_%': '52.0%',
#   'total_deaths': '3613',
#   'k/d_ratio': '1.08',
#   'damage/round': '77.5',
#   'grenadedmg/round': '4.4',
#   'maps_played': '201',
#   'rounds_played': '5412',
#   'kills/round': '0.72',
#   'assists/round': '0.12',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'fer',
#   'total_kills': '3342',
#   'headshot_%': '45.8%',
#   'total_deaths': '3150',
#   'k/d_ratio': '1.06',
#   'damage/round': '79.2',
#   'grenadedmg/round': '4.6',
#   'maps_played': '179',
#   'rounds_played': '4646',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.07'},
#  {'Name': 'ottoNd',
#   'total_kills': '4464',
#   'headshot_%': '26.0%',
#   'total_deaths': '3951',
#   'k/d_ratio': '1.13',
#   'damage/round': '72.5',
#   'grenadedmg/round': '3.3',
#   'maps_played': '242',
#   'rounds_played': '6431',
#   'kills/round': '0.69',
#   'assists/round': '0.10',
#   'death/round': '0.61',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Plopski',
#   'total_kills': '3852',
#   'headshot_%': '39.4%',
#   'total_deaths': '3626',
#   'k/d_ratio': '1.06',
#   'damage/round': '79.3',
#   'grenadedmg/round': '5.3',
#   'maps_played': '203',
#   'rounds_played': '5405',
#   'kills/round': '0.71',
#   'assists/round': '0.14',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'nawwk',
#   'total_kills': '5016',
#   'headshot_%': '32.8%',
#   'total_deaths': '4333',
#   'k/d_ratio': '1.16',
#   'damage/round': '73.1',
#   'grenadedmg/round': '2.5',
#   'maps_played': '250',
#   'rounds_played': '6811',
#   'kills/round': '0.74',
#   'assists/round': '0.09',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.11'},
#  {'Name': 'KRIMZ',
#   'total_kills': '3646',
#   'headshot_%': '40.7%',
#   'total_deaths': '3353',
#   'k/d_ratio': '1.09',
#   'damage/round': '77.1',
#   'grenadedmg/round': '3.5',
#   'maps_played': '192',
#   'rounds_played': '5194',
#   'kills/round': '0.70',
#   'assists/round': '0.14',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.10'},
#  {'Name': 'stavn',
#   'total_kills': '4220',
#   'headshot_%': '41.6%',
#   'total_deaths': '3953',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.9',
#   'grenadedmg/round': '4.2',
#   'maps_played': '212',
#   'rounds_played': '5846',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'hoody',
#   'total_kills': '3856',
#   'headshot_%': '51.0%',
#   'total_deaths': '3626',
#   'k/d_ratio': '1.06',
#   'damage/round': '78.5',
#   'grenadedmg/round': '3.7',
#   'maps_played': '198',
#   'rounds_played': '5337',
#   'kills/round': '0.72',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'FalleN',
#   'total_kills': '3186',
#   'headshot_%': '32.1%',
#   'total_deaths': '2871',
#   'k/d_ratio': '1.11',
#   'damage/round': '72.5',
#   'grenadedmg/round': '4.0',
#   'maps_played': '179',
#   'rounds_played': '4646',
#   'kills/round': '0.69',
#   'assists/round': '0.10',
#   'death/round': '0.62',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'MICHU',
#   'total_kills': '4075',
#   'headshot_%': '51.9%',
#   'total_deaths': '3820',
#   'k/d_ratio': '1.07',
#   'damage/round': '78.2',
#   'grenadedmg/round': '4.2',
#   'maps_played': '205',
#   'rounds_played': '5604',
#   'kills/round': '0.73',
#   'assists/round': '0.12',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.10'},
#  {'Name': 'f0rest',
#   'total_kills': '3467',
#   'headshot_%': '48.0%',
#   'total_deaths': '3149',
#   'k/d_ratio': '1.10',
#   'damage/round': '76.1',
#   'grenadedmg/round': '4.0',
#   'maps_played': '182',
#   'rounds_played': '4804',
#   'kills/round': '0.72',
#   'assists/round': '0.11',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'FL1T',
#   'total_kills': '5249',
#   'headshot_%': '46.7%',
#   'total_deaths': '4905',
#   'k/d_ratio': '1.07',
#   'damage/round': '76.4',
#   'grenadedmg/round': '3.9',
#   'maps_played': '277',
#   'rounds_played': '7497',
#   'kills/round': '0.70',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.12'},
#  {'Name': 'b0RUP',
#   'total_kills': '4087',
#   'headshot_%': '64.5%',
#   'total_deaths': '3878',
#   'k/d_ratio': '1.05',
#   'damage/round': '75.1',
#   'grenadedmg/round': '4.9',
#   'maps_played': '211',
#   'rounds_played': '5733',
#   'kills/round': '0.71',
#   'assists/round': '0.12',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'SHiPZ',
#   'total_kills': '4429',
#   'headshot_%': '51.3%',
#   'total_deaths': '4223',
#   'k/d_ratio': '1.05',
#   'damage/round': '78.6',
#   'grenadedmg/round': '2.8',
#   'maps_played': '228',
#   'rounds_played': '6047',
#   'kills/round': '0.73',
#   'assists/round': '0.11',
#   'death/round': '0.70',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.09'},
#  {'Name': 'zehN',
#   'total_kills': '3365',
#   'headshot_%': '47.3%',
#   'total_deaths': '3152',
#   'k/d_ratio': '1.07',
#   'damage/round': '77.6',
#   'grenadedmg/round': '6.9',
#   'maps_played': '179',
#   'rounds_played': '4722',
#   'kills/round': '0.71',
#   'assists/round': '0.13',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.07',
#   'savedteammates/round': '0.09'},
#  {'Name': 'Boombl4',
#   'total_kills': '3258',
#   'headshot_%': '42.2%',
#   'total_deaths': '3198',
#   'k/d_ratio': '1.02',
#   'damage/round': '78.2',
#   'grenadedmg/round': '4.3',
#   'maps_played': '176',
#   'rounds_played': '4693',
#   'kills/round': '0.69',
#   'assists/round': '0.13',
#   'death/round': '0.68',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.07'},
#  {'Name': 'Kjaerbye',
#   'total_kills': '3211',
#   'headshot_%': '50.0%',
#   'total_deaths': '3063',
#   'k/d_ratio': '1.05',
#   'damage/round': '77.8',
#   'grenadedmg/round': '4.6',
#   'maps_played': '175',
#   'rounds_played': '4692',
#   'kills/round': '0.68',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'CRUC1AL',
#   'total_kills': '3679',
#   'headshot_%': '31.1%',
#   'total_deaths': '3426',
#   'k/d_ratio': '1.07',
#   'damage/round': '73.3',
#   'grenadedmg/round': '2.0',
#   'maps_played': '199',
#   'rounds_played': '5186',
#   'kills/round': '0.71',
#   'assists/round': '0.09',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.11'},
#  {'Name': 'buster',
#   'total_kills': '4906',
#   'headshot_%': '48.7%',
#   'total_deaths': '4530',
#   'k/d_ratio': '1.08',
#   'damage/round': '72.3',
#   'grenadedmg/round': '3.9',
#   'maps_played': '267',
#   'rounds_played': '7239',
#   'kills/round': '0.68',
#   'assists/round': '0.11',
#   'death/round': '0.63',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.09'},
#  {'Name': 'sLowi',
#   'total_kills': '3765',
#   'headshot_%': '54.2%',
#   'total_deaths': '3601',
#   'k/d_ratio': '1.05',
#   'damage/round': '76.7',
#   'grenadedmg/round': '4.7',
#   'maps_played': '200',
#   'rounds_played': '5399',
#   'kills/round': '0.70',
#   'assists/round': '0.12',
#   'death/round': '0.67',
#   'savedbyteammate/round': '0.09',
#   'savedteammates/round': '0.08'},
#  {'Name': 'k1to',
#   'total_kills': '4462',
#   'headshot_%': '60.7%',
#   'total_deaths': '4447',
#   'k/d_ratio': '1.00',
#   'damage/round': '78.3',
#   'grenadedmg/round': '4.4',
#   'maps_played': '236',
#   'rounds_played': '6256',
#   'kills/round': '0.71',
#   'assists/round': '0.12',
#   'death/round': '0.71',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'shox',
#   'total_kills': '3918',
#   'headshot_%': '49.0%',
#   'total_deaths': '3682',
#   'k/d_ratio': '1.06',
#   'damage/round': '74.4',
#   'grenadedmg/round': '3.6',
#   'maps_played': '211',
#   'rounds_played': '5591',
#   'kills/round': '0.70',
#   'assists/round': '0.11',
#   'death/round': '0.66',
#   'savedbyteammate/round': '0.08',
#   'savedteammates/round': '0.08'},
#  {'Name': 'aizy',
#   'total_kills': '3158',
#   'headshot_%': '50.2%',
#   'total_deaths': '3048',
#   'k/d_ratio': '1.04',
#   'damage/round': '74.6',
#   'grenadedmg/round': '4.8',
#   'maps_played': '175',
#   'rounds_played': '4692',
#   'kills/round': '0.67',
#   'assists/round': '0.13',
#   'death/round': '0.65',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'},
#  {'Name': 'es3tag',
#   'total_kills': '4030',
#   'headshot_%': '36.4%',
#   'total_deaths': '3910',
#   'k/d_ratio': '1.03',
#   'damage/round': '73.4',
#   'grenadedmg/round': '5.3',
#   'maps_played': '222',
#   'rounds_played': '6083',
#   'kills/round': '0.66',
#   'assists/round': '0.14',
#   'death/round': '0.64',
#   'savedbyteammate/round': '0.10',
#   'savedteammates/round': '0.10'}]
